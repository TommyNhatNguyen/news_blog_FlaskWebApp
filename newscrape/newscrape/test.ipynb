# %%
import pandas as pd

# %%
test = pd.read_csv("vnexpress_data.csv")
test['source'] = 'vnexpress'
test
# Out:
#                                                   title  \
# 0     VietnamWorks, thương hiệu tuyển dụng thuộc Nav...
# 1     Vietnam Airlines sẽ hỗ trợ vận chuyển chuyên g...
# 2     Lỗ gần 100 tỷ đồng trong quý đầu năm, Minh Phú...
# 3     Công ty TNHH Thành phố Aqua - doanh nghiệp do ...
# 4     Masan High-Tech Materials sẽ xây dựng nhà máy ...
# ...                                                 ...
# 1163  Số lượng cổ phiếu tăng gấp đôi cổ phiếu giảm g...
# 1164  Bà Phạm Minh Hương thôi làm Chủ tịch HĐQT Công...
# 1165  Giá chuối và sản lượng tăng giúp Hoàng Anh Gia...
# 1166  Khối ngoại giải ngân chưa đến 20.000 tỷ đồng v...
# 1167  Sau một ngày tăng điểm, VN-Index chịu áp lực x...
#
#                                                 content  \
# 0     Lễ trao giải PR Awards 2023 vừa diễn ra tại Si...
# 1     Theo lễ ký kết diễn ra vào ngày 5/5 giờ London...
# 2     Báo cáo tài chính quý đầu năm của Tập đoàn Thủ...
# 3     Thông tin được Công ty TNHH Thành phố Aqua cho...
# 4     "Vonfram sẽ được thu hồi từ các sản phẩm pin v...
# ...                                                 ...
# 1163  Trước phiên giao dịch hôm nay, một số công ty ...
# 1164  Bà Hương, sinh năm 1966, bắt đầu giữ chức chủ ...
# 1165  Thông tin trên vừa được Công ty cổ phần Hoàng ...
# 1166  Nhà đầu tư nước ngoài giải ngân hơn 17.800 tỷ ...
# 1167  Hôm nay thị trường thế giới diễn biến kém tích...
#
#                                                    link       author  \
# 0     https://vnexpress.net/vietnamworks-duoc-vinh-d...          NaN
# 1     https://vnexpress.net/vietnam-airlines-dong-ha...      Anh Chi
# 2     https://vnexpress.net/vua-tom-minh-phu-lo-dam-...  Phương Đông
# 3     https://vnexpress.net/chu-dau-tu-du-an-aqua-ci...  Phương Đông
# 4     https://vnexpress.net/chien-luoc-cua-masan-tro...          NaN
# ...                                                 ...          ...
# 1163  https://vnexpress.net/chung-khoan-bien-dong-ma...  Phương Đông
# 1164  https://vnexpress.net/ba-pham-minh-huong-thoi-...  Phương Đông
# 1165  https://vnexpress.net/cong-ty-bau-duc-thu-8-ty...       Thi Hà
# 1166  https://vnexpress.net/nha-dau-tu-ngoai-rot-tie...  Phương Đông
# 1167  https://vnexpress.net/chung-khoan-chiu-ap-luc-...      Tất Đạt
#
#                                     date     source
# 0       Thứ bảy, 6/5/2023, 09:00 (GMT+7)  vnexpress
# 1       Thứ bảy, 6/5/2023, 20:00 (GMT+7)  vnexpress
# 2       Thứ sáu, 5/5/2023, 16:23 (GMT+7)  vnexpress
# 3       Thứ bảy, 6/5/2023, 13:01 (GMT+7)  vnexpress
# 4       Thứ hai, 8/5/2023, 15:00 (GMT+7)  vnexpress
# ...                                  ...        ...
# 1163   Thứ sáu, 28/4/2023, 16:06 (GMT+7)  vnexpress
# 1164   Thứ năm, 27/4/2023, 15:17 (GMT+7)  vnexpress
# 1165  Chủ nhật, 30/4/2023, 16:54 (GMT+7)  vnexpress
# 1166     Thứ ba, 2/5/2023, 07:16 (GMT+7)  vnexpress
# 1167    Thứ năm, 4/5/2023, 16:34 (GMT+7)  vnexpress
#
# [1168 rows x 6 columns]

# %%
from underthesea import sentiment
from underthesea import classify
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test_2 = pd.read_csv("vneconomy_data.csv")
test_2['source'] = 'vneconomy'
test_2
# Out:
#                                                   title  \
# 0     Cổ phiếu vào diện kiểm soát, HBC lên kế hoạch ...
# 1     Xuất hiện tin tốt về quỹ ngoại, cá nhân trong ...
# 2     NIM của những ngân hàng nào sẽ bị giảm mạnh tr...
# 3     Thanh khoản bất ngờ giảm mạnh, VN-Index “ngụp ...
# 4     Lợi nhuận quý 1/2023 kém, định giá thị trường ...
# ...                                                 ...
# 3244  Ngân hàng nào tăng trưởng lợi nhuận cao nhất t...
# 3245  Giá vàng giằng co sau báo cáo lạm phát Mỹ Giới...
# 3246  Lạm phát Mỹ lập kỷ lục mới trong tháng 6, giới...
# 3247  Rung lắc còn tiếp diễn, thị trường chờ sự đồng...
# 3248  Chứng khoán Mỹ bất ngờ chỉ giảm nhẹ sau báo cá...
#
#                                                 content  \
# 0     Sở Giao dịch Chứng khoán TP.HCM (HOSE) thông b...
# 1     Sau khi tăng thốc vào phiên giao dịch hôm qua,...
# 2     Tính đến cuối Q1/2023, tăng trưởng tín dụng to...
# 3     Dòng tiền suy yếu nghiêm trọng trong phiên chi...
# 4     Mirae Asset vừa có báo cáo triển vọng chứng kh...
# ...                                                 ...
# 3244  Trong báo cáo triển vọng lợi nhuận quý 2/2022 ...
# 3245  Giá vàng thế giới tăng rồi lại giảm sau báo cá...
# 3246  Theo dữ liệu do Cục Thống kê lao động thuộc Bộ...
# 3247  VnEconomy giới thiệu nhận định và khuyến nghị ...
# 3248  Đóng cửa phiên giao dịch ngày thứ Thư (14/7), ...
#
#                                                    link         author  \
# 0     https://vneconomy.vn/co-phieu-vao-dien-kiem-so...      Hà Anh -
# 1     https://vneconomy.vn/xuat-hien-tin-tot-ve-quy-...  Kiều Trang -
# 2     https://vneconomy.vn/nim-cua-nhung-ngan-hang-n...    Thu Minh -
# 3     https://vneconomy.vn/thanh-khoan-bat-ngo-giam-...  Kim  Phong -
# 4     https://vneconomy.vn/loi-nhuan-quy-1-2023-kem-...    Thu Minh -
# ...                                                 ...            ...
# 3244  https://vneconomy.vn/ngan-hang-nao-tang-truong...    An Nhiên -
# 3245  https://vneconomy.vn/gia-vang-giang-co-sau-bao...     Điệp Vũ -
# 3246  https://vneconomy.vn/lam-phat-my-lap-ky-luc-mo...      An Huy -
# 3247  https://vneconomy.vn/rung-lac-con-tiep-dien-th...      Hà Anh -
# 3248  https://vneconomy.vn/chung-khoan-my-bat-ngo-ch...  Ngọc Trang -
#
#                   date     source
# 0     16:18 09/05/2023  vneconomy
# 1     19:36 09/05/2023  vneconomy
# 2     19:39 09/05/2023  vneconomy
# 3     15:50 09/05/2023  vneconomy
# 4     15:53 09/05/2023  vneconomy
# ...                ...        ...
# 3244  10:05 14/07/2022  vneconomy
# 3245  11:07 14/07/2022  vneconomy
# 3246  21:27 13/07/2022  vneconomy
# 3247  21:51 13/07/2022  vneconomy
# 3248  07:04 14/07/2022  vneconomy
#
# [3249 rows x 6 columns]
